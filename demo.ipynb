# %%
# import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 3
#       1 # import pandas as pd
# ----> 3 import numpy as np
#       4 import matplotlib.pyplot as plt
#       5 import seaborn as sns
#
# ModuleNotFoundError: No module named 'numpy'

# %%
pip install numpy pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting numpy
#   Downloading numpy-2.1.1-cp312-cp312-win_amd64.whl.metadata (59 kB)
# Collecting pandas
#   Downloading pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\msf\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\msf\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading numpy-2.1.1-cp312-cp312-win_amd64.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.6 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.6 MB 1.0 MB/s eta 0:00:12
#    ----- ---------------------------------- 1.6/12.6 MB 2.7 MB/s eta 0:00:05
#    ------ --------------------------------- 2.1/12.6 MB 2.6 MB/s eta 0:00:05
#    ------- -------------------------------- 2.4/12.6 MB 2.6 MB/s eta 0:00:04
#    --------- ------------------------------ 2.9/12.6 MB 2.4 MB/s eta 0:00:04
#    --------- ------------------------------ 2.9/12.6 MB 2.4 MB/s eta 0:00:04
#    ---------- ----------------------------- 3.4/12.6 MB 2.0 MB/s eta 0:00:05
#    ----------- ---------------------------- 3.7/12.6 MB 2.1 MB/s eta 0:00:05
#    ------------- -------------------------- 4.2/12.6 MB 2.1 MB/s eta 0:00:05
#    --------------- ------------------------ 4.7/12.6 MB 2.0 MB/s eta 0:00:04
#    --------------- ------------------------ 5.0/12.6 MB 2.1 MB/s eta 0:00:04
#    ---------------- ----------------------- 5.2/12.6 MB 1.9 MB/s eta 0:00:04
#    ----------------- ---------------------- 5.5/12.6 MB 1.9 MB/s eta 0:00:04
#    ------------------ --------------------- 5.8/12.6 MB 1.8 MB/s eta 0:00:04
#    -------------------- ------------------- 6.3/12.6 MB 1.8 MB/s eta 0:00:04
#    --------------------- ------------------ 6.8/12.6 MB 1.9 MB/s eta 0:00:04
#    --------------------- ------------------ 6.8/12.6 MB 1.9 MB/s eta 0:00:04
#    ---------------------- ----------------- 7.1/12.6 MB 1.8 MB/s eta 0:00:04
#    ----------------------- ---------------- 7.3/12.6 MB 1.7 MB/s eta 0:00:04
#    ------------------------- -------------- 7.9/12.6 MB 1.7 MB/s eta 0:00:03
#    ------------------------- -------------- 8.1/12.6 MB 1.7 MB/s eta 0:00:03
#    -------------------------- ------------- 8.4/12.6 MB 1.7 MB/s eta 0:00:03
#    --------------------------- ------------ 8.7/12.6 MB 1.7 MB/s eta 0:00:03
#    ----------------------------- ---------- 9.2/12.6 MB 1.7 MB/s eta 0:00:02
#    ------------------------------ --------- 9.7/12.6 MB 1.7 MB/s eta 0:00:02
#    -------------------------------- ------- 10.2/12.6 MB 1.8 MB/s eta 0:00:02
#    --------------------------------- ------ 10.5/12.6 MB 1.8 MB/s eta 0:00:02
#    ---------------------------------- ----- 10.7/12.6 MB 1.8 MB/s eta 0:00:02
#    ----------------------------------- ---- 11.3/12.6 MB 1.8 MB/s eta 0:00:01
#    ------------------------------------- -- 11.8/12.6 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  12.3/12.6 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 1.8 MB/s eta 0:00:00
# Downloading pandas-2.2.3-cp312-cp312-win_amd64.whl (11.5 MB)
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.5 MB 4.2 MB/s eta 0:00:03
#    - -------------------------------------- 0.5/11.5 MB 4.2 MB/s eta 0:00:03
#    --- ------------------------------------ 1.0/11.5 MB 1.6 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.3/11.5 MB 1.6 MB/s eta 0:00:07
#    ------- -------------------------------- 2.1/11.5 MB 2.1 MB/s eta 0:00:05
#    --------- ------------------------------ 2.6/11.5 MB 2.2 MB/s eta 0:00:05
#    ---------- ----------------------------- 2.9/11.5 MB 2.2 MB/s eta 0:00:05
#    ---------- ----------------------------- 3.1/11.5 MB 1.9 MB/s eta 0:00:05
#    ------------- -------------------------- 3.9/11.5 MB 2.0 MB/s eta 0:00:04
#    -------------- ------------------------- 4.2/11.5 MB 2.0 MB/s eta 0:00:04
#    ---------------- ----------------------- 4.7/11.5 MB 2.0 MB/s eta 0:00:04
#    ---------------- ----------------------- 4.7/11.5 MB 2.0 MB/s eta 0:00:04
#    ------------------ --------------------- 5.2/11.5 MB 1.9 MB/s eta 0:00:04
#    -------------------- ------------------- 5.8/11.5 MB 2.0 MB/s eta 0:00:03
#    --------------------- ------------------ 6.3/11.5 MB 2.0 MB/s eta 0:00:03
#    ----------------------- ---------------- 6.8/11.5 MB 2.0 MB/s eta 0:00:03
#    ------------------------- -------------- 7.3/11.5 MB 2.0 MB/s eta 0:00:03
#    -------------------------- ------------- 7.6/11.5 MB 2.1 MB/s eta 0:00:02
#    ---------------------------- ----------- 8.1/11.5 MB 2.0 MB/s eta 0:00:02
#    ----------------------------- ---------- 8.4/11.5 MB 2.0 MB/s eta 0:00:02
#    ------------------------------ --------- 8.9/11.5 MB 2.0 MB/s eta 0:00:02
#    -------------------------------- ------- 9.4/11.5 MB 2.0 MB/s eta 0:00:02
#    ---------------------------------- ----- 10.0/11.5 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.0/11.5 MB 2.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.2/11.5 MB 1.9 MB/s eta 0:00:01
#    ------------------------------------- -- 10.7/11.5 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.5 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 2.0 MB/s eta 0:00:00
# Downloading pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Downloading tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# Installing collected packages: pytz, tzdata, numpy, pandas
# Successfully installed numpy-2.1.1 pandas-2.2.3 pytz-2024.2 tzdata-2024.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplot seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting matplot
#   Downloading matplot-0.1.9-py2.py3-none-any.whl.metadata (241 bytes)
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting pyloco>=0.0.134 (from matplot)
#   Downloading pyloco-0.0.139-py2.py3-none-any.whl.metadata (1.1 kB)
# Collecting matplotlib>=3.1.1 (from matplot)
#   Downloading matplotlib-3.9.2-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\msf\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from seaborn) (2.1.1)
# Requirement already satisfied: pandas>=1.2 in c:\users\msf\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from seaborn) (2.2.3)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.1.1->matplot)
#   Downloading contourpy-1.3.0-cp312-cp312-win_amd64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.1.1->matplot)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.1.1->matplot)
#   Downloading fonttools-4.54.1-cp312-cp312-win_amd64.whl.metadata (167 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.1.1->matplot)
#   Downloading kiwisolver-1.4.7-cp312-cp312-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\msf\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib>=3.1.1->matplot) (24.1)
# Collecting pillow>=8 (from matplotlib>=3.1.1->matplot)
#   Downloading pillow-10.4.0-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib>=3.1.1->matplot)
#   Downloading pyparsing-3.1.4-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\msf\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib>=3.1.1->matplot) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\msf\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\msf\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Collecting ushlex (from pyloco>=0.0.134->matplot)
#   Downloading ushlex-0.99.1.tar.gz (4.7 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting websocket-client (from pyloco>=0.0.134->matplot)
#   Downloading websocket_client-1.8.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting twine (from pyloco>=0.0.134->matplot)
#   Downloading twine-5.1.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting typing (from pyloco>=0.0.134->matplot)
#   Downloading typing-3.7.4.3.tar.gz (78 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting SimpleWebSocketServer (from pyloco>=0.0.134->matplot)
#   Downloading SimpleWebSocketServer-0.1.2.tar.gz (10 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: six>=1.5 in c:\users\msf\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.7->matplotlib>=3.1.1->matplot) (1.16.0)
# Collecting pkginfo>=1.8.1 (from twine->pyloco>=0.0.134->matplot)
#   Downloading pkginfo-1.11.1-py3-none-any.whl.metadata (11 kB)
# Collecting readme-renderer>=35.0 (from twine->pyloco>=0.0.134->matplot)
#   Downloading readme_renderer-44.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting requests>=2.20 (from twine->pyloco>=0.0.134->matplot)
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting requests-toolbelt!=0.9.0,>=0.8.0 (from twine->pyloco>=0.0.134->matplot)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting urllib3>=1.26.0 (from twine->pyloco>=0.0.134->matplot)
#   Downloading urllib3-2.2.3-py3-none-any.whl.metadata (6.5 kB)
# Collecting importlib-metadata>=3.6 (from twine->pyloco>=0.0.134->matplot)
#   Downloading importlib_metadata-8.5.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting keyring>=15.1 (from twine->pyloco>=0.0.134->matplot)
#   Downloading keyring-25.4.1-py3-none-any.whl.metadata (20 kB)
# Collecting rfc3986>=1.4.0 (from twine->pyloco>=0.0.134->matplot)
#   Downloading rfc3986-2.0.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Collecting rich>=12.0.0 (from twine->pyloco>=0.0.134->matplot)
#   Downloading rich-13.8.1-py3-none-any.whl.metadata (18 kB)
# Collecting pkginfo>=1.8.1 (from twine->pyloco>=0.0.134->matplot)
#   Downloading pkginfo-1.10.0-py3-none-any.whl.metadata (11 kB)
# Collecting zipp>=3.20 (from importlib-metadata>=3.6->twine->pyloco>=0.0.134->matplot)
#   Downloading zipp-3.20.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting jaraco.classes (from keyring>=15.1->twine->pyloco>=0.0.134->matplot)
#   Downloading jaraco.classes-3.4.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting jaraco.functools (from keyring>=15.1->twine->pyloco>=0.0.134->matplot)
#   Downloading jaraco.functools-4.1.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting jaraco.context (from keyring>=15.1->twine->pyloco>=0.0.134->matplot)
#   Downloading jaraco.context-6.0.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting pywin32-ctypes>=0.2.0 (from keyring>=15.1->twine->pyloco>=0.0.134->matplot)
#   Downloading pywin32_ctypes-0.2.3-py3-none-any.whl.metadata (3.9 kB)
# Collecting nh3>=0.2.14 (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot)
#   Downloading nh3-0.2.18-cp37-abi3-win_amd64.whl.metadata (1.8 kB)
# Collecting docutils>=0.21.2 (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot)
#   Downloading docutils-0.21.2-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: Pygments>=2.5.1 in c:\users\msf\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot) (2.18.0)
# Collecting charset-normalizer<4,>=2 (from requests>=2.20->twine->pyloco>=0.0.134->matplot)
#   Downloading charset_normalizer-3.3.2-cp312-cp312-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests>=2.20->twine->pyloco>=0.0.134->matplot)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.20->twine->pyloco>=0.0.134->matplot)
#   Downloading certifi-2024.8.30-py3-none-any.whl.metadata (2.2 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=12.0.0->twine->pyloco>=0.0.134->matplot)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=12.0.0->twine->pyloco>=0.0.134->matplot)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting more-itertools (from jaraco.classes->keyring>=15.1->twine->pyloco>=0.0.134->matplot)
#   Downloading more_itertools-10.5.0-py3-none-any.whl.metadata (36 kB)
# Downloading matplot-0.1.9-py2.py3-none-any.whl (5.0 kB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading matplotlib-3.9.2-cp312-cp312-win_amd64.whl (7.8 MB)
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.8 MB 5.7 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.0/7.8 MB 3.4 MB/s eta 0:00:03
#    -------- ------------------------------- 1.6/7.8 MB 3.4 MB/s eta 0:00:02
#    --------- ------------------------------ 1.8/7.8 MB 3.2 MB/s eta 0:00:02
#    ------------ --------------------------- 2.4/7.8 MB 2.4 MB/s eta 0:00:03
#    -------------- ------------------------- 2.9/7.8 MB 2.5 MB/s eta 0:00:03
#    ---------------- ----------------------- 3.1/7.8 MB 2.6 MB/s eta 0:00:02
#    -------------------- ------------------- 3.9/7.8 MB 2.5 MB/s eta 0:00:02
#    ------------------------ --------------- 4.7/7.8 MB 2.6 MB/s eta 0:00:02
#    ------------------------- -------------- 5.0/7.8 MB 2.5 MB/s eta 0:00:02
#    ------------------------- -------------- 5.0/7.8 MB 2.5 MB/s eta 0:00:02
#    ----------------------------- ---------- 5.8/7.8 MB 2.4 MB/s eta 0:00:01
#    --------------------------------- ------ 6.6/7.8 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.8/7.8 MB 2.4 MB/s eta 0:00:01
#    ------------------------------------ --- 7.1/7.8 MB 2.4 MB/s eta 0:00:01
#    ------------------------------------- -- 7.3/7.8 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------- 7.8/7.8 MB 2.2 MB/s eta 0:00:00
# Downloading pyloco-0.0.139-py2.py3-none-any.whl (60 kB)
# Downloading contourpy-1.3.0-cp312-cp312-win_amd64.whl (218 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.54.1-cp312-cp312-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    -------------- ------------------------- 0.8/2.2 MB 1.6 MB/s eta 0:00:01
#    ------------------- -------------------- 1.0/2.2 MB 1.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.3/2.2 MB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 1.8/2.2 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 1.7 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.7-cp312-cp312-win_amd64.whl (55 kB)
# Downloading pillow-10.4.0-cp312-cp312-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.6 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.6 MB 728.2 kB/s eta 0:00:03
#    ---------------- ----------------------- 1.0/2.6 MB 1.4 MB/s eta 0:00:02
#    ------------------------ --------------- 1.6/2.6 MB 1.7 MB/s eta 0:00:01
#    -------------------------------- ------- 2.1/2.6 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 2.2 MB/s eta 0:00:00
# Downloading pyparsing-3.1.4-py3-none-any.whl (104 kB)
# Downloading twine-5.1.1-py3-none-any.whl (38 kB)
# Downloading websocket_client-1.8.0-py3-none-any.whl (58 kB)
# Downloading importlib_metadata-8.5.0-py3-none-any.whl (26 kB)
# Downloading keyring-25.4.1-py3-none-any.whl (38 kB)
# Downloading pkginfo-1.10.0-py3-none-any.whl (30 kB)
# Downloading readme_renderer-44.0-py3-none-any.whl (13 kB)
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading rfc3986-2.0.0-py2.py3-none-any.whl (31 kB)
# Downloading rich-13.8.1-py3-none-any.whl (241 kB)
# Downloading urllib3-2.2.3-py3-none-any.whl (126 kB)
# Downloading certifi-2024.8.30-py3-none-any.whl (167 kB)
# Downloading charset_normalizer-3.3.2-cp312-cp312-win_amd64.whl (100 kB)
# Downloading docutils-0.21.2-py3-none-any.whl (587 kB)
#    ---------------------------------------- 0.0/587.4 kB ? eta -:--:--
#    ---------------------------------------- 0.0/587.4 kB ? eta -:--:--
#    ---------------------------------------- 587.4/587.4 kB 3.5 MB/s eta 0:00:00
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading nh3-0.2.18-cp37-abi3-win_amd64.whl (579 kB)
#    ---------------------------------------- 0.0/579.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/579.0 kB ? eta -:--:--
#    ---------------------------------------- 579.0/579.0 kB 1.7 MB/s eta 0:00:00
# Downloading pywin32_ctypes-0.2.3-py3-none-any.whl (30 kB)
# Downloading zipp-3.20.2-py3-none-any.whl (9.2 kB)
# Downloading jaraco.classes-3.4.0-py3-none-any.whl (6.8 kB)
# Downloading jaraco.context-6.0.1-py3-none-any.whl (6.8 kB)
# Downloading jaraco.functools-4.1.0-py3-none-any.whl (10 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading more_itertools-10.5.0-py3-none-any.whl (60 kB)
# Building wheels for collected packages: SimpleWebSocketServer, typing, ushlex
#   Building wheel for SimpleWebSocketServer (pyproject.toml): started
#   Building wheel for SimpleWebSocketServer (pyproject.toml): finished with status 'done'
#   Created wheel for SimpleWebSocketServer: filename=SimpleWebSocketServer-0.1.2-py3-none-any.whl size=9689 sha256=0fcfdb1f222e8edf9c25d7100ed8182ee91667046396f5369519d12fff035809
#   Stored in directory: c:\users\msf\appdata\local\pip\cache\wheels\81\fd\d8\f145b47bedceb5dff96b76e404a4ee9be956a4f8f150cd8133
#   Building wheel for typing (pyproject.toml): started
#   Building wheel for typing (pyproject.toml): finished with status 'done'
#   Created wheel for typing: filename=typing-3.7.4.3-py3-none-any.whl size=26325 sha256=154a7af4c7f4d727705a1245eaf9481dabc92723783db0e5c148887e4622c605
#   Stored in directory: c:\users\msf\appdata\local\pip\cache\wheels\12\98\52\2bffe242a9a487f00886e43b8ed8dac46456702e11a0d6abef
#   Building wheel for ushlex (pyproject.toml): started
#   Building wheel for ushlex (pyproject.toml): finished with status 'done'
#   Created wheel for ushlex: filename=ushlex-0.99.1-py3-none-any.whl size=4400 sha256=77a706d5c0a74905f746b00fd0ba7fff94ec24365c9a55b6669ff7bf4a41d63a
#   Stored in directory: c:\users\msf\appdata\local\pip\cache\wheels\42\29\49\bde2276505cc99295263e8ab2fbfd83162b3380b4b571b03bc
# Successfully built SimpleWebSocketServer typing ushlex
# Installing collected packages: ushlex, SimpleWebSocketServer, nh3, zipp, websocket-client, urllib3, typing, rfc3986, pywin32-ctypes, pyparsing, pkginfo, pillow, more-itertools, mdurl, kiwisolver, jaraco.context, idna, fonttools, docutils, cycler, contourpy, charset-normalizer, certifi, requests, readme-renderer, matplotlib, markdown-it-py, jaraco.functools, jaraco.classes, importlib-metadata, seaborn, rich, requests-toolbelt, keyring, twine, pyloco, matplot
# Successfully installed SimpleWebSocketServer-0.1.2 certifi-2024.8.30 charset-normalizer-3.3.2 contourpy-1.3.0 cycler-0.12.1 docutils-0.21.2 fonttools-4.54.1 idna-3.10 importlib-metadata-8.5.0 jaraco.classes-3.4.0 jaraco.context-6.0.1 jaraco.functools-4.1.0 keyring-25.4.1 kiwisolver-1.4.7 markdown-it-py-3.0.0 matplot-0.1.9 matplotlib-3.9.2 mdurl-0.1.2 more-itertools-10.5.0 nh3-0.2.18 pillow-10.4.0 pkginfo-1.10.0 pyloco-0.0.139 pyparsing-3.1.4 pywin32-ctypes-0.2.3 readme-renderer-44.0 requests-2.32.3 requests-toolbelt-1.0.0 rfc3986-2.0.0 rich-13.8.1 seaborn-0.13.2 twine-5.1.1 typing-3.7.4.3 urllib3-2.2.3 ushlex-0.99.1 websocket-client-1.8.0 zipp-3.20.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("housing.csv")
print(data.head())
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
data
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# 1      4 Bedroom  Theanmp       2600   5.0      3.0  120.00
# 2          3 BHK      NaN       1440   2.0      3.0   62.00
# 3          3 BHK  Soiewre       1521   3.0      1.0   95.00
# 4          2 BHK      NaN       1200   2.0      1.0   51.00
# ...          ...      ...        ...   ...      ...     ...
# 13315  5 Bedroom  ArsiaEx       3453   4.0      0.0  231.00
# 13316      4 BHK      NaN       3600   5.0      NaN  400.00
# 13317      2 BHK  Mahla T       1141   2.0      1.0   60.00
# 13318      4 BHK  SollyCl       4689   4.0      1.0  488.00
# 13319      1 BHK      NaN        550   1.0      1.0   17.00
#
# [13320 rows x 9 columns]

# %%
data.dropna(inplace = True)

# %%
data
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 5      Super built-up  Area  Ready To Move                Whitefield
# 11               Plot  Area  Ready To Move                Whitefield
# ...                     ...            ...                       ...
# 13313  Super built-up  Area  Ready To Move               Uttarahalli
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# 1      4 Bedroom  Theanmp       2600   5.0      3.0  120.00
# 3          3 BHK  Soiewre       1521   3.0      1.0   95.00
# 5          2 BHK  DuenaTa       1170   2.0      1.0   38.00
# 11     4 Bedroom  Prrry M       2785   5.0      3.0  295.00
# ...          ...      ...        ...   ...      ...     ...
# 13313      3 BHK  Aklia R       1345   2.0      1.0   57.00
# 13314      3 BHK  SoosePr       1715   3.0      3.0  112.00
# 13315  5 Bedroom  ArsiaEx       3453   4.0      0.0  231.00
# 13317      2 BHK  Mahla T       1141   2.0      1.0   60.00
# 13318      4 BHK  SollyCl       4689   4.0      1.0  488.00
#
# [7496 rows x 9 columns]

# %%
pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in c:\users\msf\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (1.5.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\msf\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn) (2.1.1)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\msf\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\msf\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\msf\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split

X = data.drop(['price'], axis = 1)
y = data['price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
train_data = X_train.join(y_train)
train_data
# Out:
#                   area_type   availability               location       size  \
# 7270   Super built-up  Area  Ready To Move  Silver Springs Layout      3 BHK
# 1808   Super built-up  Area  Ready To Move    Sector 2 HSR Layout      2 BHK
# 9006   Super built-up  Area  Ready To Move  1st Block Koramangala      3 BHK
# 9503   Super built-up  Area  Ready To Move               Sarjapur      4 BHK
# 9106   Super built-up  Area  Ready To Move            Uttarahalli      3 BHK
# ...                     ...            ...                    ...        ...
# 3009   Super built-up  Area  Ready To Move            Thanisandra      3 BHK
# 8414   Super built-up  Area  Ready To Move            Bhoganhalli      3 BHK
# 8363         Built-up  Area  Ready To Move        Old Madras Road  3 Bedroom
# 7387         Built-up  Area  Ready To Move                 Harlur      2 BHK
# 12656  Super built-up  Area  Ready To Move            Koramangala      2 BHK
#
#        society total_sqft  bath  balcony  price
# 7270   SaMTBai       1885   3.0      3.0   90.0
# 1808   Putus L       1296   2.0      1.0   75.0
# 9006   LuncyRe       1800   3.0      2.0   53.0
# 9503   Prldsum       3508   6.0      2.0  425.0
# 9106   Omy 2es       1265   2.0      2.0   65.0
# ...        ...        ...   ...      ...    ...
# 3009   Soitya        2002   3.0      2.0  112.0
# 8414   Amconi        1395   2.0      2.0   70.0
# 8363   GRlas V       2300   3.0      2.0  142.0
# 7387   Spiteid       1133   2.0      1.0   55.0
# 12656  Gencysi       1260   2.0      1.0  100.0
#
# [5996 rows x 9 columns]

# %%
train_data.hist()
# Out:
# array([[<Axes: title={'center': 'bath'}>,
#         <Axes: title={'center': 'balcony'}>],
#        [<Axes: title={'center': 'price'}>, <Axes: >]], dtype=object)

# %%
data
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 5      Super built-up  Area  Ready To Move                Whitefield
# 11               Plot  Area  Ready To Move                Whitefield
# ...                     ...            ...                       ...
# 13313  Super built-up  Area  Ready To Move               Uttarahalli
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# 1      4 Bedroom  Theanmp       2600   5.0      3.0  120.00
# 3          3 BHK  Soiewre       1521   3.0      1.0   95.00
# 5          2 BHK  DuenaTa       1170   2.0      1.0   38.00
# 11     4 Bedroom  Prrry M       2785   5.0      3.0  295.00
# ...          ...      ...        ...   ...      ...     ...
# 13313      3 BHK  Aklia R       1345   2.0      1.0   57.00
# 13314      3 BHK  SoosePr       1715   3.0      3.0  112.00
# 13315  5 Bedroom  ArsiaEx       3453   4.0      0.0  231.00
# 13317      2 BHK  Mahla T       1141   2.0      1.0   60.00
# 13318      4 BHK  SollyCl       4689   4.0      1.0  488.00
#
# [7496 rows x 9 columns]

# %%
data.drop(['area_type','availability'], axis = "columns")
# Out:
#                        location       size  society total_sqft  bath  balcony  \
# 0      Electronic City Phase II      2 BHK  Coomee        1056   2.0      1.0
# 1              Chikka Tirupathi  4 Bedroom  Theanmp       2600   5.0      3.0
# 3            Lingadheeranahalli      3 BHK  Soiewre       1521   3.0      1.0
# 5                    Whitefield      2 BHK  DuenaTa       1170   2.0      1.0
# 11                   Whitefield  4 Bedroom  Prrry M       2785   5.0      3.0
# ...                         ...        ...      ...        ...   ...      ...
# 13313               Uttarahalli      3 BHK  Aklia R       1345   2.0      1.0
# 13314         Green Glen Layout      3 BHK  SoosePr       1715   3.0      3.0
# 13315                Whitefield  5 Bedroom  ArsiaEx       3453   4.0      0.0
# 13317     Raja Rajeshwari Nagar      2 BHK  Mahla T       1141   2.0      1.0
# 13318           Padmanabhanagar      4 BHK  SollyCl       4689   4.0      1.0
#
#         price
# 0       39.07
# 1      120.00
# 3       95.00
# 5       38.00
# 11     295.00
# ...       ...
# 13313   57.00
# 13314  112.00
# 13315  231.00
# 13317   60.00
# 13318  488.00
#
# [7496 rows x 7 columns]
